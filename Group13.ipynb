# %%
# Import the required libraries.
import os
import cv2
import math
import random
import numpy as np
import datetime as dt
import tensorflow as tf
from collections import deque
import matplotlib.pyplot as plt

from moviepy.editor import *
# %matplotlib inline

from sklearn.model_selection import train_test_split

from tensorflow.keras.layers import *
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.utils import plot_model

# %%
#Capping GPU memory usage to avoid OOM
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
  try:
    tf.config.experimental.set_virtual_device_configuration(
        gpus[0],[tf.config.experimental.VirtualDeviceConfiguration(memory_limit=5500)])
  except RuntimeError as e:
    print(e)

# %%
seed_constant = 27
np.random.seed(seed_constant)
random.seed(seed_constant)
tf.random.set_seed(seed_constant)

# %%
# Create a Matplotlib figure and specify the size of the figure.
plt.figure(figsize = (20, 20))

# Get the names of all classes/categories in our dataset.
all_classes_names = os.listdir('basic_new')

# Generate a list of 4 random values. 
# where 4 is the total number of class in the dataset. 
random_range = random.sample(range(len(all_classes_names)), 4)

# Iterating through all the generated random values.
for counter, random_index in enumerate(random_range, 1):

    # Retrieve a Class Name using the Random Index.
    selected_class_Name = all_classes_names[random_index]

    # Retrieve the list of all the video files present in the randomly selected Class Directory.
    video_files_names_list = os.listdir(f'basic_new/{selected_class_Name}')

    # Randomly select a video file from the list retrieved from the randomly selected Class Directory.
    selected_video_file_name = random.choice(video_files_names_list)

    # Initialize a VideoCapture object to read from the video File.
    video_reader = cv2.VideoCapture(f'basic_new/{selected_class_Name}/{selected_video_file_name}')
    
    # Read the first frame of the video file.
    _, bgr_frame = video_reader.read()

    # Release the VideoCapture object. 
    video_reader.release()

    # Convert the frame from BGR into RGB format. 
    rgb_frame = cv2.cvtColor(bgr_frame, cv2.COLOR_BGR2RGB)

    # Write the class name on the video frame.
    cv2.putText(rgb_frame, selected_class_Name, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2)
    
    # Display the frame.
    plt.subplot(5, 4, counter);plt.imshow(rgb_frame);plt.axis('off')

# %%
# Limiting Image size to limit memory requirement
IMAGE_HEIGHT , IMAGE_WIDTH = 200, 200

# Number of frames in a sequence
SEQUENCE_LENGTH = 14

# Directory containing our dataset
DATASET_DIR = "basic_new"

# List containing the names of the classes used for training
CLASSES_LIST = ["1", "6", "8", "19"]

# %%
def frames_extraction(video_path):
    
    #List to store video frames
    frames_list = []
    
    # Reads the Video File using the VideoCapture object
    video_reader = cv2.VideoCapture(video_path)

    # Gets the total number of frames in the video
    video_frames_count = int(video_reader.get(cv2.CAP_PROP_FRAME_COUNT))

    # Calculate the the interval after which frames will be added to the list.
    skip_frames_window = max(int(video_frames_count/SEQUENCE_LENGTH), 1)

    # Iterate through the Video Frames.
    for frame_counter in range(SEQUENCE_LENGTH):

        # Set the current frame position of the video.
        video_reader.set(cv2.CAP_PROP_POS_FRAMES, frame_counter * skip_frames_window)

        # Reading the frame from the video. 
        success, frame = video_reader.read() 

        # Check if Video frame is not successfully read then break the loop
        if not success:
            break

        # Resize the Frame to fixed height and width.
        resized_frame = cv2.resize(frame, (IMAGE_HEIGHT, IMAGE_WIDTH))
        
        # Normalizing pixel value between 0 and 1
        normalized_frame = resized_frame / 255
        
        # Append the normalized frame into the frames list
        frames_list.append(normalized_frame)
    
    # Release the VideoCapture object. 
    video_reader.release()

    # Return the frames list.
    return frames_list

# %%
def create_dataset():
    
    # Declared Empty Lists to store the features, labels and video file path values.
    features = []
    labels = []
    video_files_paths = []
    
    # Iterating through all the classes mentioned in the classes list
    for class_index, class_name in enumerate(CLASSES_LIST):
        
        # Display the name of the class whose data is being extracted.
        print(f'Extracting Data of Class: {class_name}')
        
        # Get the list of video files present in the specific class name directory.
        files_list = os.listdir(os.path.join(DATASET_DIR, class_name))
        
        # Iterate through all the files present in the files list.
        for file_name in files_list:
            
            # Get the complete video path.
            video_file_path = os.path.join(DATASET_DIR, class_name, file_name)

            # Extract the frames of the video file.
            frames = frames_extraction(video_file_path)

            # Ignore the videos having frames less than the SEQUENCE_LENGTH.
            if len(frames) == SEQUENCE_LENGTH:

                # Append the data to their repective lists.
                features.append(frames)
                labels.append(class_index)
                video_files_paths.append(video_file_path)

    # Converting the list to numpy arrays
    features = np.asarray(features)
    labels = np.array(labels)  
    
    # Return the frames, class index, and video file path.
    return features, labels, video_files_paths

# %%
# Create the dataset.
features, labels, video_files_paths = create_dataset()
# Out:
# Extracting Data of Class: 1
# Extracting Data of Class: 6
# Extracting Data of Class: 8
# Extracting Data of Class: 19

# %%
# Using Keras to_categorical method to convert labels into one-hot-encoded vectors
one_hot_encoded_labels = to_categorical(labels)

# %%
# Split the Data into Train ( 75% ) and Test Set ( 25% ).
features_train, features_test, labels_train, labels_test = train_test_split(features, one_hot_encoded_labels,
                                                                            test_size = 0.25, shuffle = True,
                                                                            random_state = seed_constant)

# %%
def create_convlstm_model():

    # We will use a Sequential model for model construction
    model = Sequential()

    # Define the Model Architecture.
    ########################################################################################################################
    
    model.add(ConvLSTM2D(filters = 4, kernel_size = (3, 3), activation = 'relu',data_format = "channels_last",
                         recurrent_dropout=0.25, return_sequences=True, input_shape = (SEQUENCE_LENGTH,
                                                                                      IMAGE_HEIGHT, IMAGE_WIDTH, 3)))
    
    model.add(MaxPooling3D(pool_size=(1, 2, 2), padding='same', data_format='channels_last'))
    model.add(TimeDistributed(Dropout(0.25)))
    
    model.add(ConvLSTM2D(filters = 8, kernel_size = (3, 3), activation = 'relu', data_format = "channels_last",
                         recurrent_dropout=0.25, return_sequences=True))
    
    model.add(MaxPooling3D(pool_size=(1, 2, 2), padding='same', data_format='channels_last'))
    model.add(TimeDistributed(Dropout(0.25)))
    
    model.add(ConvLSTM2D(filters = 14, kernel_size = (3, 3), activation = 'relu', data_format = "channels_last",
                         recurrent_dropout=0.25, return_sequences=True))
    
    model.add(MaxPooling3D(pool_size=(1, 2, 2), padding='same', data_format='channels_last'))
    model.add(TimeDistributed(Dropout(0.25)))
    
    model.add(ConvLSTM2D(filters = 16, kernel_size = (3, 3), activation = 'relu', data_format = "channels_last",
                         recurrent_dropout=0.25, return_sequences=True))
    
    model.add(MaxPooling3D(pool_size=(1, 2, 2), padding='same', data_format='channels_last'))
    
    model.add(Flatten()) 
    
    model.add(Dense(len(CLASSES_LIST), activation = "softmax"))
    
    ########################################################################################################################
     
    # Display the models summary.
    model.summary()
    
    # Return the constructed convlstm model.
    return model

# %%
# Construct the required convlstm model.
convlstm_model = create_convlstm_model()

# Display the success message. 
print("Model Created Successfully!")
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv_lst_m2d (ConvLSTM2D)    (None, 14, 198, 198, 4)   1024
# _________________________________________________________________
# max_pooling3d (MaxPooling3D) (None, 14, 99, 99, 4)     0
# _________________________________________________________________
# time_distributed (TimeDistri (None, 14, 99, 99, 4)     0
# _________________________________________________________________
# conv_lst_m2d_1 (ConvLSTM2D)  (None, 14, 97, 97, 8)     3488
# _________________________________________________________________
# max_pooling3d_1 (MaxPooling3 (None, 14, 49, 49, 8)     0
# _________________________________________________________________
# time_distributed_1 (TimeDist (None, 14, 49, 49, 8)     0
# _________________________________________________________________
# conv_lst_m2d_2 (ConvLSTM2D)  (None, 14, 47, 47, 14)    11144
# _________________________________________________________________
# max_pooling3d_2 (MaxPooling3 (None, 14, 24, 24, 14)    0
# _________________________________________________________________
# time_distributed_2 (TimeDist (None, 14, 24, 24, 14)    0
# _________________________________________________________________
# conv_lst_m2d_3 (ConvLSTM2D)  (None, 14, 22, 22, 16)    17344
# _________________________________________________________________
# max_pooling3d_3 (MaxPooling3 (None, 14, 11, 11, 16)    0
# _________________________________________________________________
# flatten (Flatten)            (None, 27104)             0
# _________________________________________________________________
# dense (Dense)                (None, 4)                 108420
# =================================================================
# Total params: 141,420
# Trainable params: 141,420
# Non-trainable params: 0
# _________________________________________________________________
# Model Created Successfully!

# %%
import wandb
from wandb.keras import WandbCallback

wandb.init(config={"hyper": "parameter"})

# Create an Instance of Early Stopping Callback
# Used weights and biases callback instead
#early_stopping_callback = EarlyStopping(monitor = 'val_loss', patience = 5, mode = 'min', restore_best_weights = True)

# Compile the model and specify loss function, optimizer and metrics values to the model
convlstm_model.compile(loss = 'categorical_crossentropy', optimizer = 'Adam', metrics = ["accuracy"])

# Start training the model.
convlstm_model_training_history = convlstm_model.fit(x = features_train, y = labels_train, epochs = 100, batch_size = 10,
                                                     shuffle = True, validation_split = 0.2, 
                                                     callbacks = [WandbCallback()])
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: zebussie. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.12.16
# Run data is saved locally in <code>C:\Users\Samprad Raja Uprety\wandb\run-20220512_214234-2t6oycwf</code>
# Syncing run <strong><a href="https://wandb.ai/zebussie/uncategorized/runs/2t6oycwf" target="_blank">apricot-energy-5</a></strong> to <a href="https://wandb.ai/zebussie/uncategorized" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# wandb: WARNING The save_model argument by default saves the model in the HDF5 format that cannot save custom objects like subclassed models and custom layers. This behavior will be deprecated in a future release in favor of the SavedModel format. Meanwhile, the HDF5 model is saved as W&B files and the SavedModel as W&B Artifacts.
# Epoch 1/100
# 10/10 [==============================] - 26s 1s/step - loss: 1.4724 - accuracy: 0.2604 - val_loss: 1.3899 - val_accuracy: 0.1667
# Epoch 2/100
# 10/10 [==============================] - 9s 852ms/step - loss: 1.3750 - accuracy: 0.2917 - val_loss: 1.3866 - val_accuracy: 0.2500
# Epoch 3/100
# 10/10 [==============================] - 8s 830ms/step - loss: 1.3758 - accuracy: 0.2604 - val_loss: 1.3879 - val_accuracy: 0.2917
# Epoch 4/100
# 10/10 [==============================] - 8s 822ms/step - loss: 1.3709 - accuracy: 0.2812 - val_loss: 1.3913 - val_accuracy: 0.1250
# Epoch 5/100
# 10/10 [==============================] - 8s 820ms/step - loss: 1.3687 - accuracy: 0.2604 - val_loss: 1.3790 - val_accuracy: 0.3750
# Epoch 6/100
# 10/10 [==============================] - 8s 798ms/step - loss: 1.3431 - accuracy: 0.3021 - val_loss: 1.3671 - val_accuracy: 0.4167
# Epoch 7/100
# 10/10 [==============================] - 8s 798ms/step - loss: 1.2649 - accuracy: 0.4271 - val_loss: 1.2794 - val_accuracy: 0.5833
# Epoch 8/100
# 10/10 [==============================] - 8s 800ms/step - loss: 1.0600 - accuracy: 0.5417 - val_loss: 1.2436 - val_accuracy: 0.5417
# Epoch 9/100
# 10/10 [==============================] - 8s 811ms/step - loss: 0.8556 - accuracy: 0.6667 - val_loss: 1.1799 - val_accuracy: 0.5417
# Epoch 10/100
# 10/10 [==============================] - 8s 808ms/step - loss: 0.7040 - accuracy: 0.7292 - val_loss: 0.9804 - val_accuracy: 0.5417
# Epoch 11/100
# 10/10 [==============================] - 8s 829ms/step - loss: 0.8130 - accuracy: 0.7292 - val_loss: 0.9822 - val_accuracy: 0.6250
# Epoch 12/100
# 10/10 [==============================] - 8s 809ms/step - loss: 0.7192 - accuracy: 0.7083 - val_loss: 1.0365 - val_accuracy: 0.5417
# Epoch 13/100
# 10/10 [==============================] - 8s 812ms/step - loss: 0.5555 - accuracy: 0.7917 - val_loss: 1.0291 - val_accuracy: 0.5417
# Epoch 14/100
# 10/10 [==============================] - 8s 826ms/step - loss: 0.5774 - accuracy: 0.7188 - val_loss: 0.9700 - val_accuracy: 0.7083
# Epoch 15/100
# 10/10 [==============================] - 8s 827ms/step - loss: 0.3185 - accuracy: 0.9062 - val_loss: 0.6773 - val_accuracy: 0.7917
# Epoch 16/100
# 10/10 [==============================] - 8s 836ms/step - loss: 0.3627 - accuracy: 0.8750 - val_loss: 0.9163 - val_accuracy: 0.6667
# Epoch 17/100
# 10/10 [==============================] - 9s 860ms/step - loss: 0.2128 - accuracy: 0.9583 - val_loss: 1.0268 - val_accuracy: 0.4583
# Epoch 18/100
# 10/10 [==============================] - 8s 831ms/step - loss: 0.3282 - accuracy: 0.9167 - val_loss: 1.6364 - val_accuracy: 0.3333
# Epoch 19/100
# 10/10 [==============================] - 8s 816ms/step - loss: 0.7759 - accuracy: 0.7083 - val_loss: 0.8079 - val_accuracy: 0.7917
# Epoch 20/100
# 10/10 [==============================] - 8s 816ms/step - loss: 0.2565 - accuracy: 0.8958 - val_loss: 0.6642 - val_accuracy: 0.6667
# Epoch 21/100
# 10/10 [==============================] - 8s 847ms/step - loss: 0.3152 - accuracy: 0.9271 - val_loss: 0.7796 - val_accuracy: 0.8750
# Epoch 22/100
# 10/10 [==============================] - 8s 850ms/step - loss: 0.3142 - accuracy: 0.8958 - val_loss: 0.9215 - val_accuracy: 0.7917
# Epoch 23/100
# 10/10 [==============================] - 8s 819ms/step - loss: 0.2131 - accuracy: 0.9583 - val_loss: 0.5867 - val_accuracy: 0.8333
# Epoch 24/100
# 10/10 [==============================] - 8s 840ms/step - loss: 0.1000 - accuracy: 0.9688 - val_loss: 0.5595 - val_accuracy: 0.7917
# Epoch 25/100
# 10/10 [==============================] - 9s 881ms/step - loss: 0.1918 - accuracy: 0.9167 - val_loss: 1.6668 - val_accuracy: 0.5833
# Epoch 26/100
# 10/10 [==============================] - 8s 818ms/step - loss: 0.7793 - accuracy: 0.8646 - val_loss: 0.8354 - val_accuracy: 0.7917
# Epoch 27/100
# 10/10 [==============================] - 8s 807ms/step - loss: 0.3554 - accuracy: 0.8542 - val_loss: 0.7947 - val_accuracy: 0.7083
# Epoch 28/100
# 10/10 [==============================] - 8s 827ms/step - loss: 0.1418 - accuracy: 0.9479 - val_loss: 0.7635 - val_accuracy: 0.7083
# Epoch 29/100
# 10/10 [==============================] - 8s 815ms/step - loss: 0.2213 - accuracy: 0.9062 - val_loss: 0.8354 - val_accuracy: 0.6250
# Epoch 30/100
# 10/10 [==============================] - 8s 837ms/step - loss: 0.3226 - accuracy: 0.8750 - val_loss: 0.8261 - val_accuracy: 0.6667
# Epoch 31/100
# 10/10 [==============================] - 8s 841ms/step - loss: 0.2076 - accuracy: 0.9583 - val_loss: 0.8141 - val_accuracy: 0.6250
# Epoch 32/100
# 10/10 [==============================] - 8s 812ms/step - loss: 0.0698 - accuracy: 0.9792 - val_loss: 1.0080 - val_accuracy: 0.5833
# Epoch 33/100
# 10/10 [==============================] - 8s 819ms/step - loss: 0.1198 - accuracy: 0.9583 - val_loss: 0.7525 - val_accuracy: 0.7083
# Epoch 34/100
# 10/10 [==============================] - 8s 851ms/step - loss: 0.0608 - accuracy: 0.9688 - val_loss: 0.7832 - val_accuracy: 0.7083
# Epoch 35/100
# 10/10 [==============================] - 8s 826ms/step - loss: 0.0973 - accuracy: 0.9792 - val_loss: 0.7604 - val_accuracy: 0.7083
# Epoch 36/100
# 10/10 [==============================] - 8s 840ms/step - loss: 0.1137 - accuracy: 0.9792 - val_loss: 0.7434 - val_accuracy: 0.7083
# Epoch 37/100
# 10/10 [==============================] - 8s 807ms/step - loss: 0.1282 - accuracy: 0.9583 - val_loss: 0.7422 - val_accuracy: 0.7083
# Epoch 38/100
# 10/10 [==============================] - 8s 853ms/step - loss: 0.0283 - accuracy: 0.9896 - val_loss: 0.5582 - val_accuracy: 0.7917
# Epoch 39/100
# 10/10 [==============================] - 8s 823ms/step - loss: 0.1375 - accuracy: 0.9688 - val_loss: 0.7282 - val_accuracy: 0.7500
# Epoch 40/100
# 10/10 [==============================] - 8s 844ms/step - loss: 0.0577 - accuracy: 0.9792 - val_loss: 0.5324 - val_accuracy: 0.8333
# Epoch 41/100
# 10/10 [==============================] - 8s 814ms/step - loss: 0.0605 - accuracy: 0.9792 - val_loss: 0.5232 - val_accuracy: 0.8333
# Epoch 42/100
# 10/10 [==============================] - 8s 817ms/step - loss: 0.0755 - accuracy: 0.9792 - val_loss: 0.6018 - val_accuracy: 0.8333
# Epoch 43/100
# 10/10 [==============================] - 8s 822ms/step - loss: 0.0601 - accuracy: 0.9792 - val_loss: 0.5348 - val_accuracy: 0.7917
# Epoch 44/100
# 10/10 [==============================] - 9s 888ms/step - loss: 0.0367 - accuracy: 0.9896 - val_loss: 0.5167 - val_accuracy: 0.7917
# Epoch 45/100
# 10/10 [==============================] - 8s 836ms/step - loss: 0.0908 - accuracy: 0.9792 - val_loss: 0.5930 - val_accuracy: 0.8750
# Epoch 46/100
# 10/10 [==============================] - 8s 820ms/step - loss: 0.0284 - accuracy: 1.0000 - val_loss: 0.5200 - val_accuracy: 0.8333
# Epoch 47/100
# 10/10 [==============================] - 8s 824ms/step - loss: 0.0167 - accuracy: 1.0000 - val_loss: 0.5848 - val_accuracy: 0.7500
# Epoch 48/100
# 10/10 [==============================] - 8s 805ms/step - loss: 0.0083 - accuracy: 1.0000 - val_loss: 1.0308 - val_accuracy: 0.7083
# Epoch 49/100
# 10/10 [==============================] - 8s 834ms/step - loss: 0.0985 - accuracy: 0.9583 - val_loss: 0.5170 - val_accuracy: 0.8333
# Epoch 50/100
# 10/10 [==============================] - 8s 832ms/step - loss: 0.0831 - accuracy: 0.9792 - val_loss: 0.5492 - val_accuracy: 0.8333
# Epoch 51/100
# 10/10 [==============================] - 8s 834ms/step - loss: 0.0358 - accuracy: 1.0000 - val_loss: 0.5281 - val_accuracy: 0.7917
# Epoch 52/100
# 10/10 [==============================] - 8s 827ms/step - loss: 0.0141 - accuracy: 1.0000 - val_loss: 0.5372 - val_accuracy: 0.8333
# Epoch 53/100
# 10/10 [==============================] - 9s 863ms/step - loss: 0.1607 - accuracy: 0.9792 - val_loss: 0.8058 - val_accuracy: 0.5417
# Epoch 54/100
# 10/10 [==============================] - 8s 852ms/step - loss: 0.5773 - accuracy: 0.7812 - val_loss: 0.8443 - val_accuracy: 0.6667
# Epoch 55/100
# 10/10 [==============================] - 9s 894ms/step - loss: 0.2024 - accuracy: 0.9167 - val_loss: 0.7964 - val_accuracy: 0.7083
# Epoch 56/100
# 10/10 [==============================] - 9s 887ms/step - loss: 0.1822 - accuracy: 0.9375 - val_loss: 0.7873 - val_accuracy: 0.8750
# Epoch 57/100
# 10/10 [==============================] - 9s 863ms/step - loss: 0.1190 - accuracy: 0.9688 - val_loss: 0.5541 - val_accuracy: 0.7083
# Epoch 58/100
# 10/10 [==============================] - 9s 849ms/step - loss: 0.1306 - accuracy: 0.9583 - val_loss: 0.5164 - val_accuracy: 0.8750
# Epoch 59/100
# 10/10 [==============================] - 8s 822ms/step - loss: 0.0225 - accuracy: 0.9896 - val_loss: 0.5227 - val_accuracy: 0.7917
# Epoch 60/100
# 10/10 [==============================] - 8s 843ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.5354 - val_accuracy: 0.7083
# Epoch 61/100
# 10/10 [==============================] - 8s 847ms/step - loss: 0.0109 - accuracy: 1.0000 - val_loss: 0.5847 - val_accuracy: 0.7083
# Epoch 62/100
# 10/10 [==============================] - 8s 827ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.6049 - val_accuracy: 0.7083
# Epoch 63/100
# 10/10 [==============================] - 8s 808ms/step - loss: 0.0169 - accuracy: 0.9896 - val_loss: 0.5838 - val_accuracy: 0.7083
# Epoch 64/100
# 10/10 [==============================] - 8s 827ms/step - loss: 0.0196 - accuracy: 0.9896 - val_loss: 0.4576 - val_accuracy: 0.8333
# Epoch 65/100
# 10/10 [==============================] - 9s 876ms/step - loss: 0.1349 - accuracy: 0.9688 - val_loss: 0.5910 - val_accuracy: 0.7917
# Epoch 66/100
# 10/10 [==============================] - 9s 879ms/step - loss: 0.0641 - accuracy: 0.9688 - val_loss: 0.4085 - val_accuracy: 0.8333
# Epoch 67/100
# 10/10 [==============================] - 8s 854ms/step - loss: 0.1927 - accuracy: 0.9688 - val_loss: 0.4363 - val_accuracy: 0.8333
# Epoch 68/100
# 10/10 [==============================] - 8s 824ms/step - loss: 0.2745 - accuracy: 0.9271 - val_loss: 0.6913 - val_accuracy: 0.7083
# Epoch 69/100
# 10/10 [==============================] - 8s 841ms/step - loss: 0.1508 - accuracy: 0.9583 - val_loss: 0.5744 - val_accuracy: 0.8333
# Epoch 70/100
# 10/10 [==============================] - 8s 812ms/step - loss: 0.2870 - accuracy: 0.9062 - val_loss: 0.3408 - val_accuracy: 0.9167
# Epoch 71/100
# 10/10 [==============================] - 8s 823ms/step - loss: 0.3064 - accuracy: 0.9062 - val_loss: 0.5567 - val_accuracy: 0.8750
# Epoch 72/100
# 10/10 [==============================] - 8s 848ms/step - loss: 0.2468 - accuracy: 0.9167 - val_loss: 0.5217 - val_accuracy: 0.7917
# Epoch 73/100
# 10/10 [==============================] - 8s 852ms/step - loss: 0.0616 - accuracy: 0.9792 - val_loss: 0.6325 - val_accuracy: 0.7083
# Epoch 74/100
# 10/10 [==============================] - 8s 850ms/step - loss: 0.0085 - accuracy: 1.0000 - val_loss: 0.7828 - val_accuracy: 0.7500
# Epoch 75/100
# 10/10 [==============================] - 8s 805ms/step - loss: 0.0449 - accuracy: 0.9792 - val_loss: 0.6759 - val_accuracy: 0.7500
# Epoch 76/100
# 10/10 [==============================] - 8s 802ms/step - loss: 0.0132 - accuracy: 0.9896 - val_loss: 0.6349 - val_accuracy: 0.7917
# Epoch 77/100
# 10/10 [==============================] - 8s 818ms/step - loss: 0.0069 - accuracy: 1.0000 - val_loss: 0.5937 - val_accuracy: 0.7917
# Epoch 78/100
# 10/10 [==============================] - 8s 806ms/step - loss: 0.1222 - accuracy: 0.9688 - val_loss: 0.6542 - val_accuracy: 0.7500
# Epoch 79/100
# 10/10 [==============================] - 8s 819ms/step - loss: 0.0304 - accuracy: 1.0000 - val_loss: 0.4505 - val_accuracy: 0.7917
# Epoch 80/100
# 10/10 [==============================] - 8s 817ms/step - loss: 0.0155 - accuracy: 1.0000 - val_loss: 0.5071 - val_accuracy: 0.7500
# Epoch 81/100
# 10/10 [==============================] - 8s 852ms/step - loss: 0.0113 - accuracy: 1.0000 - val_loss: 0.5675 - val_accuracy: 0.7917
# Epoch 82/100
# 10/10 [==============================] - 8s 818ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.5835 - val_accuracy: 0.7917
# Epoch 83/100
# 10/10 [==============================] - 8s 819ms/step - loss: 0.0061 - accuracy: 1.0000 - val_loss: 0.5478 - val_accuracy: 0.7500
# Epoch 84/100
# 10/10 [==============================] - 8s 820ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.6172 - val_accuracy: 0.7500
# Epoch 85/100
# 10/10 [==============================] - 8s 826ms/step - loss: 0.0916 - accuracy: 0.9688 - val_loss: 0.5421 - val_accuracy: 0.7917
# Epoch 86/100
# 10/10 [==============================] - 8s 810ms/step - loss: 0.0714 - accuracy: 0.9896 - val_loss: 0.5501 - val_accuracy: 0.7500
# Epoch 87/100
# 10/10 [==============================] - 8s 842ms/step - loss: 0.0684 - accuracy: 0.9896 - val_loss: 0.6590 - val_accuracy: 0.7500
# Epoch 88/100
# 10/10 [==============================] - 8s 812ms/step - loss: 0.0263 - accuracy: 1.0000 - val_loss: 0.5216 - val_accuracy: 0.7500
# Epoch 89/100
# 10/10 [==============================] - 8s 828ms/step - loss: 0.0357 - accuracy: 0.9792 - val_loss: 0.5620 - val_accuracy: 0.7500
# Epoch 90/100
# 10/10 [==============================] - 8s 852ms/step - loss: 0.0812 - accuracy: 0.9792 - val_loss: 0.6128 - val_accuracy: 0.7500
# Epoch 91/100
# 10/10 [==============================] - 8s 825ms/step - loss: 0.0398 - accuracy: 0.9896 - val_loss: 0.5029 - val_accuracy: 0.7917
# Epoch 92/100
# 10/10 [==============================] - 8s 808ms/step - loss: 0.0269 - accuracy: 0.9896 - val_loss: 0.3807 - val_accuracy: 0.7917
# Epoch 93/100
# 10/10 [==============================] - 8s 814ms/step - loss: 0.0117 - accuracy: 1.0000 - val_loss: 0.3761 - val_accuracy: 0.8333
# Epoch 94/100
# 10/10 [==============================] - 8s 858ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.3961 - val_accuracy: 0.8333
# Epoch 95/100
# 10/10 [==============================] - 8s 829ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.4380 - val_accuracy: 0.8333
# Epoch 96/100
# 10/10 [==============================] - 8s 838ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.4593 - val_accuracy: 0.7917
# Epoch 97/100
# 10/10 [==============================] - 8s 824ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.4781 - val_accuracy: 0.7917
# Epoch 98/100
# 10/10 [==============================] - 8s 839ms/step - loss: 7.7960e-04 - accuracy: 1.0000 - val_loss: 0.4946 - val_accuracy: 0.7917
# Epoch 99/100
# 10/10 [==============================] - 8s 824ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.4913 - val_accuracy: 0.8333
# Epoch 100/100
# 10/10 [==============================] - 8s 825ms/step - loss: 4.4485e-04 - accuracy: 1.0000 - val_loss: 0.4935 - val_accuracy: 0.8333

# %%
# Evaluate the trained model.
model_evaluation_history = convlstm_model.evaluate(features_test, labels_test)
# Out:
# 2/2 [==============================] - 1s 426ms/step - loss: 0.6624 - accuracy: 0.8250

# %%
# Get the loss and accuracy from model_evaluation_history.
model_evaluation_loss, model_evaluation_accuracy = model_evaluation_history

# Define the string date format.
# Get the current Date and Time in a DateTime Object.
# Convert the DateTime object to string according to the style mentioned in date_time_format string.
date_time_format = '%Y_%m_%d__%H_%M_%S'
current_date_time_dt = dt.datetime.now()
current_date_time_string = dt.datetime.strftime(current_date_time_dt, date_time_format)

# Define a useful name for our model to make it easy for us while navigating through multiple saved models.
model_file_name = f'convlstm_model___Date_Time_{current_date_time_string}___Loss_{model_evaluation_loss}___Accuracy_{model_evaluation_accuracy}.h5'

# Save your Model.
convlstm_model.save(model_file_name)

# %%
def plot_metric(model_training_history, metric_name_1, metric_name_2, plot_name):
 
    # Get metric values using metric names as identifiers.
    metric_value_1 = model_training_history.history[metric_name_1]
    metric_value_2 = model_training_history.history[metric_name_2]
    
    # Construct a range object which will be used as x-axis (horizontal plane) of the graph.
    epochs = range(len(metric_value_1))

    # Plot the Graph.
    plt.plot(epochs, metric_value_1, 'blue', label = metric_name_1)
    plt.plot(epochs, metric_value_2, 'red', label = metric_name_2)

    # Add title to the plot.
    plt.title(str(plot_name))

    # Add legend to the plot.
    plt.legend()

# %% [markdown]
# Now we will utilize the function **`plot_metric()`** created above, to visualize and understand the metrics.

# %%
# Visualize the training and validation loss metrices.
plot_metric(convlstm_model_training_history, 'loss', 'val_loss', 'Total Loss vs Total Validation Loss')

# %%
# Visualize the training and validation accuracy metrices.
plot_metric(convlstm_model_training_history, 'accuracy', 'val_accuracy', 'Total Accuracy vs Total Validation Accuracy')
